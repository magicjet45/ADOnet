# %%
#------------Import Data---------------

csv_path_ann= ('DoOR.csv')
X_ann = pd.read_csv(csv_path_ann)

#---------------------Odor Classifier()---------------------------
class Odor_classifier(nn.Module):
  def __init__(self,input_dim,output_dim):
    super().__init__()
    self.net=nn.Sequential(
        nn.Linear(input_dim,615),
        nn.ReLU(),
        nn.Linear(615,4907),
        nn.ReLU(),
        nn.Linear(4907,output_dim)
    )
  def forward(self, x):
    return self.net(x)

model = Odor_classifier(input_dim=2278, output_dim=250).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

#-----------------------Train & Test----------------------
cls_labels = []
for i in range(250):
  cls_labels.append(f'Odor_({i+1})')

le=LabelEncoder()
y_int=le.fit_transform(cls_labels)
y = y_int
y_out=torch.tensor(y,dtype=torch.long)

x_train=[]
y_train=[]
x_test=[]
y_test=[]

idx=torch.randint(0,250,(1000,))

for n in idx:
  noise=torch.normal(mean=0,std=0.2,size=(2278,))

  # Exclude the first column 'Unnamed_0' and convert to numeric, coercing errors
  xi = pd.to_numeric(X_ann.iloc[n.item(), 1:], errors='coerce')
  xn  = torch.zeros(2278, dtype=torch.float32)
  # Fill potential NaN values with 0 before converting to tensor
  xn = torch.tensor(xi.fillna(0).values, dtype=torch.float32) + noise # Convert pandas Series to tensor
  x_train.append(xn)
  y_train.append(y_out[n]) # Append the individual element y_out[n]

idx=torch.randint(0,250,(200,))

for k in idx:
  noise=torch.normal(mean=0,std=0.2,size=(2278,))

  # Exclude the first column 'Unnamed_0' and convert to numeric, coercing errors
  xi = pd.to_numeric(X_ann.iloc[k.item(), 1:], errors='coerce')
  xn  = torch.zeros(2278, dtype=torch.float32)
  # Fill potential NaN values with 0 before converting to tensor
  xn = torch.tensor(xi.fillna(0).values, dtype=torch.float32) + noise # Convert pandas Series to tensor
  x_test.append(xn)
  y_test.append(y_out[k]) # Append the individual element y_out[k]

x_train = torch.stack(x_train).to(dtype=torch.float32)
y_train = torch.stack(y_train).to(dtype=torch.long)
x_test = torch.stack(x_test).to(dtype=torch.float32)
y_test = torch.stack(y_test).to(dtype=torch.long)

train_ds = TensorDataset(x_train, y_train)
test_ds  = TensorDataset(x_test,  y_test)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
test_loader  = DataLoader(test_ds,  batch_size=64, shuffle=False)

#---------------Train loop----------------

num_epochs = 100
train_losses_0, train_accs_0 = [], []

for epoch in trange(num_epochs, desc="Epochs"):
    model.train()
    tr_loss = tr_acc = 0.0
    y_true = []
    y_pred = []
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss   = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        tr_loss += loss.item() * xb.size(0)
        tr_acc  += (logits.argmax(dim=1) == yb).float().sum().item()

        # for confusion matrix
        y_true.append(yb.cpu())
        y_pred.append(logits.argmax(dim=1).cpu())

    tr_loss /= len(train_loader.dataset)
    tr_acc  /= len(train_loader.dataset)
    train_losses_0.append(tr_loss)
    train_accs_0.append(tr_acc)

    print(f"Epoch {epoch+1:02d}/{num_epochs}  "
          f"Train Loss: {tr_loss:.4f}, Acc: {tr_acc:.4%}  ")


#------------Test Accuracy---------
model.eval()
te_correct = 0
total_samples = 0
with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        logits = model(xb)
        te_correct += (logits.argmax(dim=1) == yb).float().sum().item()
        total_samples += xb.size(0)
test_acc_0 = te_correct / total_samples
print(f"Test set accuracy: {test_acc_0:.4%}")


#---------Train result plot---------
fig, ax1 = plt.subplots(figsize=(8, 4))
# Loss: 왼쪽 y축
ax1.plot(train_losses_0, color='tab:blue', label='Train Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
# Accuracy: 오른쪽 y축
ax2 = ax1.twinx()
ax2.plot(train_accs_0, color='tab:orange', label='Train Acc')
ax2.set_ylabel('Accuracy', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='center right')

plt.title('Train Loss & Accuracy')
plt.show()


# ---------Confusion_matrix---------
y_true_all = torch.cat(y_true).numpy()
y_pred_all = torch.cat(y_pred).numpy()

cm = confusion_matrix(y_true_all, y_pred_all)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epochs:   3%|▎         | 3/100 [00:00<00:22,  4.34it/s]
# Epoch 01/100  Train Loss: 5.5171, Acc: 1.0000%
# Epoch 02/100  Train Loss: 5.3885, Acc: 6.9000%
# Epoch 03/100  Train Loss: 5.1974, Acc: 10.2000%
# Epochs:   5%|▌         | 5/100 [00:00<00:14,  6.68it/s]
# Epoch 04/100  Train Loss: 4.9296, Acc: 13.8000%
# Epoch 05/100  Train Loss: 4.5464, Acc: 21.6000%
# Epoch 06/100  Train Loss: 4.0315, Acc: 34.0000%
# Epochs:   9%|▉         | 9/100 [00:01<00:09, 10.00it/s]
# Epoch 07/100  Train Loss: 3.4133, Acc: 58.1000%
# Epoch 08/100  Train Loss: 2.7584, Acc: 75.7000%
# Epoch 09/100  Train Loss: 2.1168, Acc: 88.1000%
# Epochs:  11%|█         | 11/100 [00:01<00:08, 11.08it/s]
# Epoch 10/100  Train Loss: 1.5703, Acc: 94.2000%
# Epoch 11/100  Train Loss: 1.1148, Acc: 98.1000%
# Epoch 12/100  Train Loss: 0.7784, Acc: 98.5000%
# Epochs:  15%|█▌        | 15/100 [00:01<00:06, 12.30it/s]
# Epoch 13/100  Train Loss: 0.5371, Acc: 99.4000%
# Epoch 14/100  Train Loss: 0.3670, Acc: 100.0000%
# Epoch 15/100  Train Loss: 0.2608, Acc: 100.0000%
# Epochs:  17%|█▋        | 17/100 [00:01<00:06, 12.71it/s]
# Epoch 16/100  Train Loss: 0.1833, Acc: 100.0000%
# Epoch 17/100  Train Loss: 0.1390, Acc: 100.0000%
# Epoch 18/100  Train Loss: 0.1080, Acc: 100.0000%
# Epochs:  21%|██        | 21/100 [00:02<00:05, 13.17it/s]
# Epoch 19/100  Train Loss: 0.0878, Acc: 100.0000%
# Epoch 20/100  Train Loss: 0.0715, Acc: 100.0000%
# Epoch 21/100  Train Loss: 0.0605, Acc: 100.0000%
# Epochs:  23%|██▎       | 23/100 [00:02<00:05, 13.31it/s]
# Epoch 22/100  Train Loss: 0.0520, Acc: 100.0000%
# Epoch 23/100  Train Loss: 0.0457, Acc: 100.0000%
# Epoch 24/100  Train Loss: 0.0406, Acc: 100.0000%
# Epochs:  27%|██▋       | 27/100 [00:02<00:05, 13.53it/s]
# Epoch 25/100  Train Loss: 0.0364, Acc: 100.0000%
# Epoch 26/100  Train Loss: 0.0327, Acc: 100.0000%
# Epoch 27/100  Train Loss: 0.0299, Acc: 100.0000%
# Epochs:  29%|██▉       | 29/100 [00:02<00:05, 13.48it/s]
# Epoch 28/100  Train Loss: 0.0272, Acc: 100.0000%
# Epoch 29/100  Train Loss: 0.0250, Acc: 100.0000%
# Epoch 30/100  Train Loss: 0.0232, Acc: 100.0000%
# Epochs:  33%|███▎      | 33/100 [00:03<00:04, 13.52it/s]
# Epoch 31/100  Train Loss: 0.0216, Acc: 100.0000%
# Epoch 32/100  Train Loss: 0.0201, Acc: 100.0000%
# Epoch 33/100  Train Loss: 0.0187, Acc: 100.0000%
# Epochs:  35%|███▌      | 35/100 [00:03<00:04, 13.63it/s]
# Epoch 34/100  Train Loss: 0.0176, Acc: 100.0000%
# Epoch 35/100  Train Loss: 0.0165, Acc: 100.0000%
# Epoch 36/100  Train Loss: 0.0155, Acc: 100.0000%
# Epochs:  39%|███▉      | 39/100 [00:03<00:04, 13.71it/s]
# Epoch 37/100  Train Loss: 0.0147, Acc: 100.0000%
# Epoch 38/100  Train Loss: 0.0139, Acc: 100.0000%
# Epoch 39/100  Train Loss: 0.0132, Acc: 100.0000%
# Epochs:  41%|████      | 41/100 [00:03<00:04, 13.64it/s]
# Epoch 40/100  Train Loss: 0.0126, Acc: 100.0000%
# Epoch 41/100  Train Loss: 0.0120, Acc: 100.0000%
# Epoch 42/100  Train Loss: 0.0114, Acc: 100.0000%
# Epochs:  45%|████▌     | 45/100 [00:03<00:04, 13.48it/s]
# Epoch 43/100  Train Loss: 0.0109, Acc: 100.0000%
# Epoch 44/100  Train Loss: 0.0104, Acc: 100.0000%
# Epoch 45/100  Train Loss: 0.0100, Acc: 100.0000%
# Epochs:  47%|████▋     | 47/100 [00:04<00:03, 13.44it/s]
# Epoch 46/100  Train Loss: 0.0096, Acc: 100.0000%
# Epoch 47/100  Train Loss: 0.0092, Acc: 100.0000%
# Epoch 48/100  Train Loss: 0.0089, Acc: 100.0000%
# Epochs:  51%|█████     | 51/100 [00:04<00:03, 13.60it/s]
# Epoch 49/100  Train Loss: 0.0085, Acc: 100.0000%
# Epoch 50/100  Train Loss: 0.0082, Acc: 100.0000%
# Epoch 51/100  Train Loss: 0.0080, Acc: 100.0000%
# Epochs:  53%|█████▎    | 53/100 [00:04<00:03, 13.66it/s]
# Epoch 52/100  Train Loss: 0.0077, Acc: 100.0000%
# Epoch 53/100  Train Loss: 0.0074, Acc: 100.0000%
# Epoch 54/100  Train Loss: 0.0072, Acc: 100.0000%
# Epochs:  57%|█████▋    | 57/100 [00:04<00:03, 13.65it/s]
# Epoch 55/100  Train Loss: 0.0070, Acc: 100.0000%
# Epoch 56/100  Train Loss: 0.0068, Acc: 100.0000%
# Epoch 57/100  Train Loss: 0.0066, Acc: 100.0000%
# Epochs:  59%|█████▉    | 59/100 [00:04<00:03, 13.51it/s]
# Epoch 58/100  Train Loss: 0.0064, Acc: 100.0000%
# Epoch 59/100  Train Loss: 0.0062, Acc: 100.0000%
# Epoch 60/100  Train Loss: 0.0060, Acc: 100.0000%
# Epochs:  63%|██████▎   | 63/100 [00:05<00:02, 13.63it/s]
# Epoch 61/100  Train Loss: 0.0059, Acc: 100.0000%
# Epoch 62/100  Train Loss: 0.0057, Acc: 100.0000%
# Epoch 63/100  Train Loss: 0.0056, Acc: 100.0000%
# Epochs:  65%|██████▌   | 65/100 [00:05<00:02, 13.62it/s]
# Epoch 64/100  Train Loss: 0.0055, Acc: 100.0000%
# Epoch 65/100  Train Loss: 0.0053, Acc: 100.0000%
# Epoch 66/100  Train Loss: 0.0052, Acc: 100.0000%
# Epochs:  69%|██████▉   | 69/100 [00:05<00:02, 13.53it/s]
# Epoch 67/100  Train Loss: 0.0051, Acc: 100.0000%
# Epoch 68/100  Train Loss: 0.0050, Acc: 100.0000%
# Epoch 69/100  Train Loss: 0.0049, Acc: 100.0000%
# Epochs:  71%|███████   | 71/100 [00:05<00:02, 13.49it/s]
# Epoch 70/100  Train Loss: 0.0048, Acc: 100.0000%
# Epoch 71/100  Train Loss: 0.0047, Acc: 100.0000%
# Epoch 72/100  Train Loss: 0.0046, Acc: 100.0000%
# Epochs:  75%|███████▌  | 75/100 [00:06<00:01, 13.53it/s]
# Epoch 73/100  Train Loss: 0.0045, Acc: 100.0000%
# Epoch 74/100  Train Loss: 0.0044, Acc: 100.0000%
# Epoch 75/100  Train Loss: 0.0044, Acc: 100.0000%
# Epochs:  77%|███████▋  | 77/100 [00:06<00:01, 13.52it/s]
# Epoch 76/100  Train Loss: 0.0043, Acc: 100.0000%
# Epoch 77/100  Train Loss: 0.0042, Acc: 100.0000%
# Epoch 78/100  Train Loss: 0.0041, Acc: 100.0000%
# Epochs:  81%|████████  | 81/100 [00:06<00:01, 13.73it/s]
# Epoch 79/100  Train Loss: 0.0041, Acc: 100.0000%
# Epoch 80/100  Train Loss: 0.0040, Acc: 100.0000%
# Epoch 81/100  Train Loss: 0.0039, Acc: 100.0000%
# Epochs:  83%|████████▎ | 83/100 [00:06<00:01, 13.66it/s]
# Epoch 82/100  Train Loss: 0.0039, Acc: 100.0000%
# Epoch 83/100  Train Loss: 0.0038, Acc: 100.0000%
# Epoch 84/100  Train Loss: 0.0038, Acc: 100.0000%
# Epochs:  87%|████████▋ | 87/100 [00:06<00:00, 13.58it/s]
# Epoch 85/100  Train Loss: 0.0037, Acc: 100.0000%
# Epoch 86/100  Train Loss: 0.0037, Acc: 100.0000%
# Epoch 87/100  Train Loss: 0.0036, Acc: 100.0000%
# Epochs:  89%|████████▉ | 89/100 [00:07<00:00, 13.56it/s]
# Epoch 88/100  Train Loss: 0.0036, Acc: 100.0000%
# Epoch 89/100  Train Loss: 0.0036, Acc: 100.0000%
# Epoch 90/100  Train Loss: 0.0035, Acc: 100.0000%
# Epochs:  93%|█████████▎| 93/100 [00:07<00:00, 13.61it/s]
# Epoch 91/100  Train Loss: 0.0035, Acc: 100.0000%
# Epoch 92/100  Train Loss: 0.0034, Acc: 100.0000%
# Epoch 93/100  Train Loss: 0.0034, Acc: 100.0000%
# Epochs:  95%|█████████▌| 95/100 [00:07<00:00, 12.93it/s]
# Epoch 94/100  Train Loss: 0.0034, Acc: 100.0000%
# Epoch 95/100  Train Loss: 0.0033, Acc: 100.0000%
# Epoch 96/100  Train Loss: 0.0033, Acc: 100.0000%
# Epochs:  99%|█████████▉| 99/100 [00:07<00:00, 12.20it/s]
# Epoch 97/100  Train Loss: 0.0033, Acc: 100.0000%
# Epoch 98/100  Train Loss: 0.0033, Acc: 100.0000%
# Epoch 99/100  Train Loss: 0.0032, Acc: 100.0000%
# Epochs: 100%|██████████| 100/100 [00:08<00:00, 12.44it/s]
# Epoch 100/100  Train Loss: 0.0032, Acc: 100.0000%
# Test set accuracy: 87.5000%
