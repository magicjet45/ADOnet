# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
plt.grid(True)
# 2) Accuracy: 오른쪽 y축에 train_accs_1a~1d, train_accs_2d
acc_series = {
    'Random': train_accs_1a,
    'Syn': train_accs_1b,
    'Syn_Norm': train_accs_1c
}
for name, accs in acc_series.items():
    ax1.plot(accs, label=f'Train Acc {name}')
ax1.set_ylabel('Accuracy')
ax1.tick_params(axis='y')
ax1.set_xlabel('Epoch')
ax2 = ax1.twinx()
ax2.plot(train_accs_0, label='Train Acc FC-Layer', color='black', linestyle='--')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1+lines_2, labels_1+labels_2, loc='center right')

plt.title('Train Accuracy for DoOR input')
plt.xlabel('Epoch')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
plt.grid(True)
# 2) Accuracy: 오른쪽 y축에 train_accs_1a~1d, train_accs_2d

ax1.plot(train_accs_1c, label='Train Acc Syn_Norm', color='orange')
ax1.plot(train_accs_1c_a, label='Train Acc Mix_OtP', color='green')
ax1.plot(train_accs_1c_b, label='Train Acc Mix_PtK', color='blue')
ax1.plot(train_accs_1c_c, label='Train Acc Mix_OtK', color='red')

ax1.set_ylabel('Accuracy')

ax1.tick_params(axis='y')
ax1.set_xlabel('Epoch')
ax2 = ax1.twinx()
ax2.plot(train_accs_0, label='Train Acc FC-Layer', color='black', linestyle='--')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1+lines_2, labels_1+labels_2, loc='center right')

plt.title('Train Accuracy for DoOR input')
plt.xlabel('Epoch')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
plt.grid(True)
# 2) Accuracy: 오른쪽 y축에 train_accs_1a~1d, train_accs_2d

ax1.plot(train_accs_1c, label='Train Acc Syn_Norm', color='orange')
ax1.plot(train_accs_1c_1, label='Train Acc Rand_OtP', color='green')
ax1.plot(train_accs_1c_2, label='Train Acc Rand_PtK', color='blue')
ax1.plot(train_accs_1a, label='Train Acc Rand_OtK', color='red')

ax1.set_ylabel('Accuracy')

ax1.tick_params(axis='y')
ax1.set_xlabel('Epoch')
ax2 = ax1.twinx()
ax2.plot(train_accs_0, label='Train Acc FC-Layer', color='black', linestyle='--')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1+lines_2, labels_1+labels_2, loc='center right')

plt.title('Train Accuracy for DoOR input')
plt.xlabel('Epoch')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
plt.grid(True)
# 2) Accuracy: 오른쪽 y축에 train_accs_1a~1d, train_accs_2d

ax1.plot(train_accs_1c_a, label='Index_Mix_OtP', color='green')
ax1.plot(train_accs_1c_b, label='Index_Mix_PtK', color='blue')
ax1.plot(train_accs_1c_c, label='Index_Mix_OtK', color='red')

ax1.plot(train_accs_1c, label='Train Acc Syn_Norm', color='orange')
ax1.plot(train_accs_1c_1, label='Value_Rand_OtP', color='green',linestyle='--')
ax1.plot(train_accs_1c_2, label='Value_Rand_PtK', color='blue',linestyle='--')
ax1.plot(train_accs_1a, label='Value_Rand_OtK', color='red',linestyle='--')

ax1.set_ylabel('Accuracy')

ax1.tick_params(axis='y')
ax1.set_xlabel('Epoch')

lines_1, labels_1 = ax1.get_legend_handles_labels()
ax1.legend(lines_1, labels_1, loc='center right')

plt.title('Train Accuracy for DoOR input')
plt.xlabel('Epoch')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
plt.grid(True)
# 2) Accuracy: 오른쪽 y축에 train_accs_1a~1d, train_accs_2d
acc_series = {
    'Random': train_accs_2a,
    'Syn': train_accs_2b,
    'Syn_Norm': train_accs_2c
}
ax1.plot(train_accs_1a, label= 'Train Acc Random(DoOR)', color='skyblue', linestyle='--')
for name, accs in acc_series.items():
    ax1.plot(accs, label=f'Train Acc {name}')
ax1.set_ylabel('Accuracy')
ax1.tick_params(axis='y')


lines_1, labels_1 = ax1.get_legend_handles_labels()
ax1.legend(lines_1, labels_1, loc='center right')

plt.title('Train Accuracy for Random input')
plt.xlabel('Epoch')
plt.show()

# %%
# (헤더=0, 평균·표준편차 행은 읽지 않음)
df = pd.read_excel('testmix.xlsx', nrows=15)

plt.figure(figsize=(6,5))
plt.boxplot([df[col] for col in df.columns], labels=df.columns, showmeans=True)

plt.ylabel('Test Accuracy')
plt.title('Test Accuracy Distribution (15 runs)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-23-1594089844.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[col] for col in df.columns], labels=df.columns, showmeans=True)
